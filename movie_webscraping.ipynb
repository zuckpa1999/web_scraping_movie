# %%
import requests
import os
import csv
url = "https://www.imdb.com/search/title/?genres=comedy&groups=top_250&sort=user_rating,desc" # url ของเว็บที่ต้องการดูข้อมูล
data = requests.get(url)
print(data.status_code)
print(data.text)
# Out:
# 200
#
#
#
# <!DOCTYPE html>
# <html
#     xmlns:og="http://ogp.me/ns#"
#     xmlns:fb="http://www.facebook.com/2008/fbml">
#     <head>
#
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///?src=mdot">
#
#
#
#         <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
#
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
#   <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
#         <title>Comedy,
# IMDb &quot;Top 250&quot;
# (Sorted by IMDb Rating Descending) - IMDb</title>
#   <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
# ...

# %%
import requests
url = "https://www.imdb.com/search/title/?genres=comedy&groups=top_250&sort=user_rating,desc"
data = requests.get(url)
###############
from bs4 import BeautifulSoup
soup = BeautifulSoup(data.text,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>
#   <script type="text/javascript">
#    var IMDbTimer={starttime: new Date().getTime(),pt:'java'};
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <title>
#    Comedy,
# IMDb "Top 250"
# (Sorted by IMDb Rating Descending) - IMDb
#   </title>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# ...

# %%
x = soup.find_all("img",{"class":"loadlate"}) # <- ค่าที่ใช้ในการค้นหา

for i in x:
    print(i.get("alt"))
    print("\n")
# Out:
# Gisaengchung
#
#
# La vita è bella
#
#
# The Intouchables
#
#
# Back to the Future
#
#
# Modern Times
#
#
# City Lights
#
#
# 3 Idiots
#
#
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
#
#
# The Great Dictator
#
#
# Toy Story 3
#
#
# Amélie
#
#
# Snatch
#
#
# Toy Story
#
#
# The Sting
#
#
# The Apartment
#
#
# Singin' in the Rain
#
#
# The Kid
#
#
# Green Book
#
#
# Three Billboards Outside Ebbing, Missouri
#
#
# Klaus
#
#
# Inside Out
#
#
# Gangs of Wasseypur
#
#
# Up
#
#
# Rang De Basanti
#
#
# Lock, Stock and Two Smoking Barrels
#
#
# Monty Python and the Holy Grail
#
#
# Some Like It Hot
#
#
# The Gold Rush
#
#
# Sherlock Jr.
#
#
# Relatos salvajes
#
#
# PK
#
#
# The Grand Budapest Hotel
#
#
# Mary and Max
#
#
# Finding Nemo
#
#
# The Truman Show
#
#
# The Big Lebowski
#
#
# Dead Poets Society
#
#
# Life of Brian
#
#
# Mr. Smith Goes to Washington
#
#
# It Happened One Night
#
#
# The General
#
#
# Monsters, Inc.
#
#
# Aladdin

# %%
import csv

for link in soup.find_all('a'):
    x = 1
    with open('mhovie.csv', 'w', newline='') as file:
        writer = csv.writer(file)
        if x==1:
            writer.writerow("Movie name")
            x = x +1    
        print(link.get('href'))
        writer.writerow(link.get('href'))
        print("\n")
# Out:
# /?ref_=nv_home
#
#
# https://www.imdb.com/showtimes/?ref_=nv_mv_sh
#
#
# https://m.imdb.com/showtimes/movie/?ref_=nv_mv_sh
#
#
# /chart/top/?ref_=nv_mv_250
#
#
# /chart/moviemeter/?ref_=nv_mv_mpm
#
#
# https://www.imdb.com/feature/genre/?ref_=nv_ch_gr
#
#
# /chart/boxoffice/?ref_=nv_ch_cht
#
#
# https://www.imdb.com/movies-in-theaters/?ref_=nv_mv_inth
#
#
# https://m.imdb.com/coming-soon/?ref_=nv_mv_cs
#
#
# https://www.imdb.com/coming-soon/?ref_=nv_mv_cs
#
#
# https://www.imdb.com/list/ls016522954/?ref_=nv_tvv_dvd
#
#
# https://www.imdb.com/calendar/?ref_=nv_mv_cal
#
#
# /news/movie/?ref_=nv_nw_mv
#
#
# /india/toprated/?ref_=nv_mv_in
#
#
# /chart/toptv/?ref_=nv_tvv_250
#
#
# /chart/tvmeter/?ref_=nv_tvv_mptv
#
#
# https://www.imdb.com/feature/genre/?ref_=nv_tv_gr
#
#
# /news/tv/?ref_=nv_nw_tv
#
#
# /india/tv?ref_=nv_tv_in
#
#
# /oscars/?ref_=nv_ev_acd
#
#
# https://m.imdb.com/feature/bestpicture/?ref_=nv_ch_osc
#
#
# ...

# %%
# if os.path.exists("movie.csv"):
#     os.remove("movie.csv")
#     print("deleted existing move.csv file")
# else:
#   print("The file does not exist, we will create it soon")
# with open('movie.csv', 'w', newline='') as file:
#     writer = csv.writer(file)
#     writer.writerow(["Movie name","rating"])
#     writer.writerow(i.get("alt"))

#adding movie name
x = soup.find_all("img",{"class":"loadlate"}) # <- ค่าที่ใช้ในการค้นหา
#initialize list
movie_name=[]
for i in x:
    #print(i.get("alt").strip())
    words = i.get("alt").strip()
    #print("\n")
    movie_name.append(words)
    
# adding rating
metascore = soup.find_all("span",{"class":"metascore"}) # <- ค่าที่ใช้ในการค้นหา
#initialize list
rating=[]
for i in metascore:
    #print(i.text)
    word = i.text.strip()
    rating.append(word)
#     print("\n")
#     list.append(i.get("alt"))

# # adding description
# Description = soup.find_all("p",{"class":"text-muted"}) # <- ค่าที่ใช้ในการค้นหา
# #initialize list
# desc=[]
# for i in Description:
#     print(i.text)
#     wordss = i.text.strip()
#     desc.append(wordss)







#  n = 1
#     with open('mhovie.csv', 'w', newline='') as file:
#         writer = csv.writer(file)
#         if n==1:
#             writer.writerow("Movie name")
#             x = x +1    
#         print(link.get('href'))
#         writer.writerow(link.get('href'))
#         print("\n")

# %%
# if os.path.exists("movie.csv"):
#     os.remove("movie.csv")
#     print("deleted existing move.csv file")
# else:
#   print("The file does not exist, we will create it soon")


#adding movie name into  movie.csv file

with open('movie.csv', 'w',encoding="utf-8") as f:
    writer = csv.writer(f)
    for val in movie_name:
        val = val.strip()
        writer.writerow([val])   
with open('movie.csv',newline='') as f:
    r = csv.reader(f)
    data = [line for line in r]
with open('movie.csv','w',newline='') as f:
    w = csv.writer(f)
    w.writerow(['Movie Name'])
    w.writerows(data)
print("HT")
# Out:
# HT

# %%
# # adding description
# Description = soup.find_all("p",{"class":"text-muted"}) # <- ค่าที่ใช้ในการค้นหา
# #initialize list
# desc=[]
# for i in Description:
#     print(i)
#     wordss = i.text.strip()
#     desc.append(wordss)
